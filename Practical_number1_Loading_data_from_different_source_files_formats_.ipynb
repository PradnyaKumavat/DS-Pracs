# %% [markdown]
# <a href="https://colab.research.google.com/github/PradnyaKumavat/DS-Pracs/blob/main/Practical_number1_Loading_data_from_different_source_files_formats_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aim of this Practical is to Understand most commonly used file formats in Machine Learning & Data Science (using Python)

# %% [markdown]
# ## What is a file format?
#
# A file format is a standard way in which information is encoded for storage in a file.
#
# First, the file format specifies whether the file is a binary or ASCII file.
#
# Second, it shows how the information is organized.
#
# For example, comma-separated values (CSV) file format stores tabular data in plain text.

# %% [markdown]
# Choosing the optimal file format for storing data can improve the performance of your models in data processing.
#
# Now, we will look at the following file formats and how to read them in Python:

# %% [markdown]
# -Comma-separated values
#
# -XLSX
#
# -ZIP
#
# -Plain Text (txt)
#
# -JSON
#
# -XML
#
# -HTML
#
# -Images

# %% [markdown]
# ## 1. Comma-separated values
#
# Comma-separated values file format falls under spreadsheet file format.

# %% [markdown]
# What is Spreadsheet File Format?
#
# In spreadsheet file format, data is stored in cells. Each cell is organized in rows and columns. A column in the spreadsheet file can have different types. For example, a column can be of string type, a date type or an integer type. Some of the most popular spreadsheet file formats are Comma Separated Values ( CSV ), Microsoft Excel Spreadsheet ( xls ) and Microsoft Excel Open XML Spreadsheet ( xlsx ).
#
# Each line in CSV file represents an observation or commonly called a record. Each record may contain one or more fields which are separated by a comma.
#
# Sometimes you may come across files where fields are not separated by using a comma but they are separated using tab. This file format is known as TSV (Tab Separated Values) file format

# %%
# Reading the data from CSV in Python

import pandas as pd

df = pd.read_csv(“/home/Loan_Prediction/train.csv”) # Different Location File

df1 = pd.read_csv(“train.csv”) # Same File

# Above code will load the train.csv file in DataFrame df.
print(df)

# %% [markdown]
# ## 2. XLSX files
#
# XLSX is a Microsoft Excel Open XML file format. It also comes under the Spreadsheet file format. It is an XML-based file format created by Microsoft Excel. The XLSX format was introduced with Microsoft Office 2007.
#
# In XLSX data is organized under the cells and columns in a sheet. Each XLSX file may contain one or more sheets. So a workbook can contain multiple sheets.

# %%
# Reading the data from XLSX file

import pandas as pd

df = pd.read_excel(“/home/Loan_Prediction/train.xlsx”, sheetname = “Invoice”)

# Above code will load the sheet “Invoice” from “train.xlsx” file in DataFrame df.
print(df)

# %% [markdown]
# ## 4. Plain Text (txt) file format

# %% [markdown]
# In Plain Text file format, everything is written in plain text.
#
# Usually, this text is in unstructured form and there is no meta-data associated with it.
#
# The txt file format can easily be read by any program.
#
# But interpreting this is very difficult by a computer program.

# %%
# Suppose the above text written in a file called text.txt and you want to read this so you can refer the below code.

text_file = open("text.txt", "r")
lines = text_file.read()
print(lines)
# Out:
# In my previous article, I introduced you to the basics of Apache Spark, different data representations
# (RDD / DataFrame / Dataset) and basics of operations (Transformation and Action). We even solved a machine
# learning problem from one of our past hackathons. In this article, I will continue from the place I left in
# my previous article. I will focus on manipulating RDD in PySpark by applying operations
# (Transformation and Actions).

# %% [markdown]
# ## 8. Image files
# Image files are probably the most fascinating file format used in data science.
#
# Any computer vision application is based on image processing. So it is necessary to know different image file formats.
#
# Usual image files are 3-Dimensional, having RGB values.
#
# But, they can also be 2-Dimensional (grayscale) or 4-Dimensional (having intensity) – an Image consisting of pixels and meta-data associated with it.
#
# Each image consists one or more frames of pixels.
#
# And each frame is made up of two-dimensional array of pixel values. Pixel values can be of any intensity.  Meta-data associated with an image, can be an image type (.png) or pixel dimensions.

# %%
# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read Images
img = mpimg.imread('dog.jpg')

# Output Images
plt.imshow(img)

# %%
# image using PIL module

# importing PIL
from PIL import Image

# Read image
img = Image.open('dog.jpg')

# Output Images
img.show()

# prints format of image
print(img.format)

# prints mode of image
print(img.mode)
# Out:
# JPEG
# RGB

# %% [markdown]
# # Summarizing data with statistics

# %%
# importing libraries
import pandas as pd


# Create dataframe
data = {'name': ['A', 'B', 'C', 'D', 'E'],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data, columns = ['name', 'age', 'preTestScore', 'postTestScore'])
df
# Out:
#   name  age  preTestScore  postTestScore
# 0    A   42             4             25
# 1    B   52            24             94
# 2    C   36            31             57
# 3    D   24             2             62
# 4    E   73             3             70

# %%
# Looking Statistically on data

# The sum of all the ages
df['age'].sum()
# Out:
# 227

# %%
# Mean of preTestScore

df['preTestScore'].mean()
# Out:
# 12.8

# %%
# Cumulative sum of preTestScores, moving from the rows from the top

df['preTestScore'].cumsum()
# Out:
# 0     4
# 1    28
# 2    59
# 3    61
# 4    64
# Name: preTestScore, dtype: int64

# %%
# Summary statistics on preTestScore

df['preTestScore'].describe()
# Out:
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: preTestScore, dtype: float64

# %%
# Count the number of non-NA values

df['preTestScore'].count()
# Out:
# 5

# %%
# Minimum value of preTestScore

df['preTestScore'].min()
# Out:
# 2

# %%
# Maximum value of preTestScore

df['preTestScore'].max()
# Out:
# 31

# %%
# Median value of preTestScore

df['preTestScore'].median()
# Out:
# 4.0

# %%
# Sample variance of preTestScore values

df['preTestScore'].var()
# Out:
# 186.7

# %%
# Sample standard deviation of preTestScore values

df['preTestScore'].std()
# Out:
# 13.663820841916802

# %%
# Skewness of preTestScore values

df['preTestScore'].skew()
# Out:
# 0.7433452457326751

# %%
# Kurtosis of preTestScore values

df['preTestScore'].kurt()
# Out:
# -2.4673543738411547

# %%
# Correlation Matrix Of Values
df.corr()
# Out:
#                     age  preTestScore  postTestScore
# age            1.000000     -0.105651       0.328852
# preTestScore  -0.105651      1.000000       0.378039
# postTestScore  0.328852      0.378039       1.000000

# %%
# Covariance Matrix Of Values
df.cov()
# Out:
#                   age  preTestScore  postTestScore
# age            340.80        -26.65         151.20
# preTestScore   -26.65        186.70         128.65
# postTestScore  151.20        128.65         620.30

# %%
import pandas as pd
import numpy as np

# Create a sample dataset
np.random.seed(42)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'Age': np.random.randint(18, 25, 5),
    'Grade': np.random.uniform(60, 100, 5),
    'Hours_Studied': np.random.randint(5, 20, 5)
}

df = pd.DataFrame(data)

# Display the dataset
print("Sample Dataset:")
print(df)
print("\n")

# Summary statistics for numeric columns
numeric_summary = df.describe()
print("Summary Statistics for Numeric Columns:")
print(numeric_summary)
print("\n")

# Summary statistics for categorical columns
categorical_summary = df.describe(include='object')
print("Summary Statistics for Categorical Columns:")
print(categorical_summary)
print("\n")

# Correlation matrix
correlation_matrix = df.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Sample Dataset:
#       Name  Age      Grade  Hours_Studied
# 0    Alice   24  91.187640              9
# 1      Bob   21  83.874006              8
# 2  Charlie   22  77.833310             12
# 3    David   24  63.998997             12
# 4     Emma   20  78.369956              7
#
#
# Summary Statistics for Numeric Columns:
#              Age      Grade  Hours_Studied
# count   5.000000   5.000000       5.000000
# mean   22.200000  79.052782       9.600000
# std     1.788854   9.988353       2.302173
# min    20.000000  63.998997       7.000000
# 25%    21.000000  77.833310       8.000000
# 50%    22.000000  78.369956       9.000000
# 75%    24.000000  83.874006      12.000000
# max    24.000000  91.187640      12.000000
#
#
# Summary Statistics for Categorical Columns:
#          Name
# count       5
# unique      5
# top     Alice
# freq        1
#
#
# Correlation Matrix:
#                     Age     Grade  Hours_Studied
# Age            1.000000 -0.130031       0.631336
# Grade         -0.130031  1.000000      -0.568336
# Hours_Studied  0.631336 -0.568336       1.000000
# <ipython-input-1-5d8758d25b70>:33: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# r=1 indicates a perfect positive correlation (as one variable increases, the other also increases proportionally).
#
# r=-1 indicates a perfect negative correlation (as one variable increases, the other decreases proportionally).
#
# r=0 indicates no linear correlation between the variables.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example dataset
data = {
    'Hours_Studied': [2, 3, 4, 5, 6, 7, 8, 9],
    'Exam_Score': [50, 55, 60, 65, 70, 75, 80, 120]
}

df = pd.DataFrame(data)

# Calculate and visualize correlation
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Calculate correlation coefficient
correlation_coefficient = df['Hours_Studied'].corr(df['Exam_Score'])
print(f"Correlation Coefficient: {correlation_coefficient:.2f}")
# Out:
# Correlation Coefficient: 0.89

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Extended example dataset
data = {
    'Hours_Studied': [2, 3, 4, 5, 6, 7, 8, 9],
    'Exam_Score': [50, 55, 60, 65, 70, 75, 80, 85],
    'Sleep_Hours': [5, 6, 7, 7, 8, 8, 9, 10]
}

df = pd.DataFrame(data)

# Calculate and visualize correlation
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Calculate correlation coefficients
correlation_hours_score = df['Hours_Studied'].corr(df['Exam_Score'])
correlation_hours_sleep = df['Hours_Studied'].corr(df['Sleep_Hours'])
correlation_score_sleep = df['Exam_Score'].corr(df['Sleep_Hours'])

print(f"Correlation Coefficient (Hours_Studied vs. Exam_Score): {correlation_hours_score:.2f}")
print(f"Correlation Coefficient (Hours_Studied vs. Sleep_Hours): {correlation_hours_sleep:.2f}")
print(f"Correlation Coefficient (Exam_Score vs. Sleep_Hours): {correlation_score_sleep:.2f}")
# Out:
# Correlation Coefficient (Hours_Studied vs. Exam_Score): 1.00
# Correlation Coefficient (Hours_Studied vs. Sleep_Hours): 0.98
# Correlation Coefficient (Exam_Score vs. Sleep_Hours): 0.98

# %%
# Negative correlation example
data_negative = {
    'Study_Hours': [2, 3, 4, 5, 6, 7, 8, 9],
    'Exam_Score': [90, 85, 80, 75, 70, 65, 60, 55]
}

df_negative = pd.DataFrame(data_negative)

# Calculate and visualize correlation
correlation_matrix_negative = df_negative.corr()
sns.heatmap(correlation_matrix_negative, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Negative Correlation Heatmap')
plt.show()

# %%
# Combined visualization
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.heatmap(correlation_matrix_positive, annot=True, cmap='coolwarm', fmt=".1f")
plt.title('Positive Correlation')

plt.subplot(1, 2, 2)
sns.heatmap(correlation_matrix_negative, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Negative Correlation')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Dataset with higher variance (Class A)
data_high_variance = {'Exam_Score': [60, 75, 45, 90, 30]}
df_high_variance = pd.DataFrame(data_high_variance)
print(df_high_variance.mean())

# Calculate sample variance
sample_variance_high = df_high_variance['Exam_Score'].var()

print("Sample Variance (Class A):", sample_variance_high)
# Out:
# Exam_Score    60.0
# dtype: float64
# Sample Variance (Class A): 562.5

# %%
# Dataset with lower variance (Class B)
data_low_variance = {'Exam_Score': [82, 85, 80, 88, 78]}
df_low_variance = pd.DataFrame(data_low_variance)

print(df_low_variance.mean())

# Calculate sample variance
sample_variance_low = df_low_variance['Exam_Score'].var()

print("Sample Variance (Class B):", sample_variance_low)
# Out:
# Exam_Score    82.6
# dtype: float64
# Sample Variance (Class B): 15.799999999999999

# %% [markdown]
# **Higher Variance Scenario (Class A):**
#
# The exam scores in Class A are more spread out. Some students scored significantly higher or lower than the average. This could indicate a diverse range of performance levels.
#
# **Lower Variance Scenario (Class B):**
#
# The exam scores in Class B are closer to each other. Most students scored around the class average, suggesting a more consistent performance across the class.

# %%
# Frequency distribution for a categorical variable
category_counts = df['Name'].value_counts()
print("Frequency Distribution for 'Category':")
print(category_counts)
# Out:
# Frequency Distribution for 'Category':
# Alice      1
# Bob        1
# Charlie    1
# David      1
# Emma       1
# Name: Name, dtype: int64

# %%
df.nunique()
# Out:
# Name             5
# Age              4
# Grade            5
# Hours_Studied    4
# dtype: int64
